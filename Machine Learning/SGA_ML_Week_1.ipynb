# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# Numeric Feature

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Scalling
#
# hanya berguna di non tree base model
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Ourliers
#
# KLIP atau Drop

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Rank

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Categorical(non peringkat) and Ordinal(peringkat)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# tidak disarankan untuk non tree model

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# lebih aman pakai ini

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# MISSING VALUE
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Mean untuk data yang jenis normal dan median untuk yang gambar bawah

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# target encoding

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Label Encodng

# %%
bang kalau data test harus di scalling tidak?
